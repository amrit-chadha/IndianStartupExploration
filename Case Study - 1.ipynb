# %% [markdown]
# # Number of Fundings

# %%
from collections import Counter
import pandas as pd
data = pd.read_csv('startup_funding.csv', skipinitialspace=True)
# data['Date'][34:]

data['Date'] = data['Date'].str.replace('/', '.')
data['Date'] = data['Date'].str.split('.')
data['Year'] = data['Date'].str[-1].astype(int)
data['AmountInUSD'] = data['AmountInUSD'].str.replace(',', '')
data = data.fillna(0)

yearDic = Counter(data['Year'])

for year in sorted(yearDic.keys()):
    print(year, yearDic[year])
# Out:
# 2015 936
# 2016 993
# 2017 443

# %% [markdown]
# # Top Indian Cities

# %%
from collections import Counter
import pandas as pd
import operator
data = pd.read_csv('startup_funding.csv', skipinitialspace=True)

data = data.fillna('None')

rep = {'delhi': 'new delhi'}

data['CityLocation'] = data.CityLocation.str.lower()
data['CityLocation'] = data['CityLocation'].str.partition('/')
data['CityLocation'] = data['CityLocation'].str.strip()
data['CityLocation'] = data.CityLocation.replace(rep)
data = Counter(data['CityLocation'])
del data['none']

data = sorted(data.items(), key=operator.itemgetter(1), reverse=True)[:10]

for i in data:
    name = ' '.join([x.capitalize() for x in i[0].split()])
    print(name, i[1])
# Out:
# Bangalore 635
# Mumbai 449
# New Delhi 389
# Gurgaon 241
# Pune 91
# Noida 79
# Hyderabad 77
# Chennai 67
# Ahmedabad 35
# Jaipur 25

# %% [markdown]
# # Funding amount

# %%
from collections import Counter
import pandas as pd
import operator
data = pd.read_csv('startup_funding.csv', skipinitialspace=True)

# Empty values fill
data['AmountInUSD'] = data['AmountInUSD'].fillna('0,0')
data['CityLocation'] = data['CityLocation'].fillna('None')

# AmountInUSD contains ','
data['AmountInUSD'] = data['AmountInUSD'].str.replace(',','')
data['AmountInUSD'] = data['AmountInUSD'].astype(int)

# Delhi -> New Delhi
rep = {'delhi': 'new delhi'}

# Banglore, banglore/us -> 'banglore' only
data['CityLocation'] = data.CityLocation.str.lower()
data['CityLocation'] = data['CityLocation'].str.partition('/')
data['CityLocation'] = data['CityLocation'].str.strip()
data['CityLocation'] = data.CityLocation.replace(rep)

data = data.groupby('CityLocation').sum()

# Unneccessary columns and rows
data = data.drop(index='none')
data = data.drop(columns='SNo')

# finding the top10 cities
top10 = data.sort_values(by=['AmountInUSD'], ascending=False)[:10]
totalFunding = top10['AmountInUSD'].sum()

# Converting df to dict
for key, value in top10.to_dict()['AmountInUSD'].items():
    # new delhi -> 'New Delhi'
    key = ' '.join([x.capitalize() for x in key.split()])
    value = (value / totalFunding) * 100
    print ('{} {:.2f}'.format(key, value))
# Out:
# Bangalore 49.71
# New Delhi 16.63
# Mumbai 13.90
# Gurgaon 12.21
# Chennai 2.43
# Pune 2.16
# Hyderabad 1.15
# Noida 1.01
# Ahmedabad 0.58
# Jaipur 0.21

# %% [markdown]
# # Investment Type

# %%
from collections import Counter
import pandas as pd
import operator
data = pd.read_csv('startup_funding.csv', skipinitialspace=True)

# Empty values fill
data['AmountInUSD'] = data['AmountInUSD'].fillna('0,0')
data['InvestmentType'] = data['InvestmentType'].fillna('None')

# AmountInUSD contains ','
data['AmountInUSD'] = data['AmountInUSD'].str.replace(',','')
data['AmountInUSD'] = data['AmountInUSD'].astype(int)

# Investment type name fix
data['InvestmentType'] = data['InvestmentType'].str.lower()
data['InvestmentType'] = data['InvestmentType'].str.replace(' ', '')

totalinvestment = data['AmountInUSD'].sum()

rep = {'privateequity': 'Private Equity', 'seedfunding': 'Seed Funding', 
       'debtfunding': 'Debt Funding', 'crowdfunding': 'Crowd Funding'}

data['InvestmentType'] = data['InvestmentType'].replace(rep)


investment_dict = Counter(data['InvestmentType'])
del investment_dict['none']

for key in investment_dict:
    investment_dict[key] = (data[data['InvestmentType'] == key]['AmountInUSD'].sum() / totalinvestment) * 100
    print("{} {:.2f}".format(key, investment_dict[key]))
# Out:
# Private Equity 98.15
# Seed Funding 1.81
# Debt Funding 0.04
# Crowd Funding 0.00

# %% [markdown]
# # Top Industries

# %%
from collections import Counter
import pandas as pd
import operator
data = pd.read_csv('startup_funding.csv', skipinitialspace=True)

# Empty values fill
data['AmountInUSD'] = data['AmountInUSD'].fillna('0,0')
data = data.fillna('None')

rep = {'ecommerce': 'Ecommerce', 'consumer interne': 'consumer internet'}

data['IndustryVertical'] = data['IndustryVertical'].str.lower()
data['IndustryVertical'] = data['IndustryVertical'].replace(rep)
sorted(Counter(data['IndustryVertical']))
# Out:
# ['360-degree view creating platform',
#  '3d printer manufacturer',
#  'Ecommerce',
#  'activity based social network',
#  'advertising & marketing community networking platform',
#  'affordable education',
#  'affordable hotel booking online',
#  'affordable personal healthcare products',
#  'algorithmic match making platform',
#  'alternate mobile monetization platform',
#  'anonymous bulletin board app',
#  'api workflow platform',
#  'app analytics platform',
#  'app based bus pooling services',
#  'app based fitness coaching',
#  'app security\xa0 testing platform',
#  'architectural design & consulting',
#  'artificial intelligence ecommerce chatbot',
#  'artificial intelligence platform',
#  'artist / designer marketplace',
#  'asset financing platform',
#  'auto',
#  'auto insurance online platform',
#  'auto rickshaw based logistics',
#  'auto rickshaw based services',
#  'automated storage & warehousing solution',
#  'automotive services platform',
#  'autorickshaw aggregator & booking platform',
#  'b2b ecommerce marketplace',
#  'b2b logistics delivery platform',
#  'b2b marketplace for industrial goods',
#  'b2b merchandize platform',
#  'b2b mobile auction marketplace',
#  'b2c messaging app',
#  'banking analytics platform',
#  'beauty & lifestyle mobile marketplace',
#  'beauty & lifestyle platform',
#  'beauty & wellness mobile app',
#  'beauty & wellness products e-tailer',
#  'beauty & wellness services marketplace',
#  'beauty and wellness marketplace',
#  'beauty and wellness platform',
#  'beauty services mobile marketplace',
#  'bespoke merchandize marketplace',
#  'bfsi',
#  'big data & analytics platform',
#  'big data & analytics services',
#  'big data & predictive analysis platform',
#  'big data analytics platform',
#  'big data management platform',
#  'bike rental platform',
#  'bike, appliances renting marketplace',
#  'brain games platform',
#  'brand licensing startup',
#  'branded budget hotel marketplace',
#  'branded food products online sales',
#  'budget accommodation aggregator',
#  'budget accommodation platform',
#  'budget hotel accommodation',
#  'budget hotel accommodation brand',
#  'budget hotels aggregator',
#  'bus aggregation and rental mobile app',
#  'bus ticketing and fleet management platform',
#  'business and it consulting',
#  'business expense management',
#  'business intelligence & analytics',
#  'business it intelligence services',
#  'business messaging app',
#  'cab aggregator',
#  'cab booking app platform',
#  'cab rental mobile app',
#  'cab search comparison & booking platform',
#  'cab sharing service mobile app',
#  'car & bike ecommerce platform',
#  'car aggregator & retail mobile app',
#  'car maintenance & management mobile app',
#  'career community for women',
#  'career development',
#  'casual dating app',
#  'casual dining restaurant chain',
#  'celebrity fashion brand',
#  'chain of tea café’s',
#  'character merchandize sales platform',
#  'chat based personal assistant app',
#  'chinese food delivery',
#  'citizens engagement platform',
#  'clean tech',
#  'clinical genomics provider',
#  'cloud based collaboration platform',
#  'cloud based hotel sales platform',
#  'cloud data integration platform',
#  'cloud enterprise mobility platform',
#  'cloud enterprise software',
#  'cloud software solutions',
#  'cloud-based hotel booking platform',
#  'clud based learning platform',
#  'community driven news/views platform',
#  'competitive exam learning platform',
#  'consumer internet',
#  'consumer lending marketplace',
#  'contact center software platform',
#  'content discovery & reward points platform',
#  'content management software solutions',
#  'content-based subscription ecommerce platform',
#  'conversational commerce mobile app',
#  'corporate wellness app',
#  'coupon aggregator platform',
#  'coupons and cashback aggregator app',
#  'credit card fraud protection solutions',
#  'credit management services',
#  'cricket management mobile game',
#  'crm / analytics platform',
#  'cross-channel crm platform',
#  'cross-device retargeting platform',
#  'crowd funding platform',
#  'crowdsourced delivery platform',
#  'curated freelancer marketplace',
#  'custom furniture marketplace',
#  'custom made furniture e-tailer',
#  'custom merchandize platform',
#  'customer engagement platform',
#  'dairy based product manufacturer',
#  'data analytics platform',
#  'data center software platform',
#  'data driven publishing platform',
#  'data driven recruitment recommendation',
#  'data science & ux design learning platform',
#  'deep learning cloud algorithms',
#  'delivery & logistics service provider',
#  'dental clinic chain',
#  'designer fashion jewellery marketplace',
#  'designer merchandize marketplace',
#  'developer portfolio showcase platform',
#  'device repair svcs',
#  'diagnostic labs aggregator platform',
#  'digital & physical publishing platform',
#  'digital / mobile wallet',
#  'digital analytics platform',
#  'digital coupons, deal & cashback aggregator app',
#  'digital healthcare',
#  'digital intelligent learning platform',
#  'digital marketing automation solution',
#  'digital marketing services',
#  'digital media platform',
#  'digital media publishing platform',
#  'digital signal processing platform',
#  'doctor appointment booking app',
#  'doctor consultancy mobile app',
#  'doctors network mobile app',
#  'document digitization platform',
#  'domestic help aggregation platform',
#  'e-commerce & m-commerce platform',
#  'e-learning service provider',
#  'early cancer detection solutions',
#  'easy business loans platform',
#  'ecommerce brands’ full service agency',
#  'ecommerce data analytics platform',
#  'ecommerce delivery locker services',
#  'ecommerce discount & cashback coupons platform',
#  'ecommerce logistics',
#  'ecommerce logistics provider',
#  'ecommerce marketing software platform',
#  'ecommerce marketplace',
#  'ecommerce platform',
#  'ecommerce platform solutions',
#  'ecommerce product recommendation platform',
#  'ecommerce product search engine',
#  'ecommerce related software product platform',
#  'ecommerce returns etailer',
#  'ecommerce website creation saas platform',
#  'ed-tech',
#  'ed-tech platform',
#  'education',
#  'education content etailer',
#  'education content provider',
#  'education marketplace',
#  'educational board games',
#  'efficient energy management platform',
#  'elearning platform',
#  'electric bike manufacturers',
#  'electric scooter manufacturer',
#  'electronic goods recycling service',
#  'employee onboarding & orientation platform',
#  'end to end reverse logistics solution platform',
#  'end-to-end lending platform',
#  'end-to-end logistics platform',
#  'energy & environment online marketplace',
#  'energy saving solutions provider',
#  'engineering innovations',
#  'engineering services company',
#  'enterprise communication platform',
#  'enterprise marketing automation platform',
#  'ethnic beverages manufacturer',
#  'ethnic product ecommerce',
#  'ethnic/ traditional fashion store',
#  'event ticketing platform',
#  'event venue booking platform',
#  'exam preparation platform',
#  'exclusive platform for doctors & healthcare professionals',
#  'express local delivery platform',
#  'extra curricular activities marketplace app',
#  'f&b sector mobile payment platform',
#  'fashion discovery platform',
#  'fashion ecommerce',
#  'fashion ecommerce store',
#  'fashion info aggregator app',
#  'fashion jewelry and accessories e-tailer',
#  'fashion search & review platform',
#  'fast food chain franchisee',
#  'finance',
#  'financial inclusion platform',
#  'financial markets software',
#  'financial products lead generation platform',
#  'financial services platform',
#  'financial services portal',
#  'financial tech',
#  'fine dining restaurant chain',
#  'fintech startup incubation platform',
#  'fitness marketplace',
#  'fitness tracking management solutions',
#  'flat rental mobile app',
#  'fmcg',
#  'food & beverage',
#  'food & beverages',
#  'food customer analytics platform',
#  'food delivery platform',
#  'food discovery & delivery mobile app',
#  'food discovery & table booking app',
#  'food discovery app',
#  'food logistics & delivery',
#  'food ordering & delivery app',
#  'food subscription platform',
#  'freight logistics platform',
#  'fund raising platform',
#  'fund raising platform for startups',
#  'furniture and appliances rental platform',
#  'gesture based mobile development',
#  'global community for travellers',
#  'global healthcare products',
#  'gourmet food discovery & delivery platform',
#  'gourmet meals delivery',
#  'government test preparation platform',
#  'grey collar job board',
#  'grocery delivery platform',
#  'grocery retail mobile app',
#  'gym & fitness studios subscription platform',
#  'gym discovery platform',
#  'hasbro toy manufacturer',
#  'health & fitness app',
#  'health and beauty services marketplace',
#  'health mobile app',
#  'health, wellness & beauty services app',
#  'health-tech platform',
#  'healthcare',
#  'healthcare consulting platform',
#  'healthcare it solutions & services',
#  'healthcare mobile app',
#  'healthcare services discovery platform',
#  'healthcareservice provider',
#  'healthy food manufacturer',
#  'healthy food online community',
#  'healthy meals food delivery platform',
#  'hiring analytics platform',
#  'holiday resort chain',
#  'home cooked food marketplace & delivery',
#  'home cooked food order & delivery platform',
#  'home design & décor platform',
#  'home design & décor solutions',
#  'home fitting & fixtures marketplace',
#  'home furnishing solutions',
#  'home healthcare services platform,',
#  'home improvement service platform',
#  'home made food marketplace',
#  'home medical care services',
#  'home rental platform',
#  'home services marketplace',
#  'home stay & room rentals platform',
#  'hotel aggregator & booking platform',
#  'hotel booking app',
#  'hotel mobile crm software platform',
#  'hyper local logistics platform',
#  'hyper-local ecommerce',
#  'hyper-local grocery delivery platform',
#  'hyper-local online services',
#  'hyper-local online/mobile grocery',
#  'hyperlocal deals marketplace',
#  'hyperlocal delivery platform',
#  'hyperlocal delivery services',
#  'hyperlocal electronics repair service',
#  'hyperlocal food & grocery store',
#  'hyperlocal goods marketplace',
#  'hyperlocal grocery app',
#  'hyperlocal grocery delivery',
#  'hyperlocal handyman services',
#  'hyperlocal healthcare product delivery service provider',
#  'hyperlocal logistics service',
#  'hyperlocal logistics service provider',
#  'hyperlocal maintenance, repair & cleaning services',
#  'hyperlocal mobile marketplace',
#  'hyperlocal mobile services marketplace',
#  'hyperlocal on-demand household services platform',
#  'hyperlocal online home services provider',
#  'hyperlocal online services platform',
#  'hyperlocal services marketplace',
#  'hyperlocal shopping app',
#  'hyperlocal\xa0 grocery delivery service',
#  'indian ethnic crafts etailer',
#  'indoor navigation & analytics solutions',
#  'industrial supplies b2b ecommerce',
#  'industrial tools marketplace',
#  'industrial toons marketplace',
#  'innovative water solutions',
#  'intelligent data analytics',
#  'interactive educational games',
#  'interactive\xa0 how-to guides',
#  'interface development platform for government officials',
#  'international hiring platform',
#  'internet network infrastructure services',
#  'internet of things platform',
#  'intra-city logistics service',
#  'investment management platform',
#  'iot energy management analytics platform',
#  'it / customer engagement consulting',
#  'it infrastructure & data center services',
#  'job board',
#  'job search platform',
#  'kids tool kit for innovation platform',
#  'language learning app',
#  'language localization cloud platform',
#  'last mile delivery service',
#  'last mile logistics',
#  'last minute hotel booking app',
#  'last minute travel deals mobile marketplace',
#  'lifestyle ecommerce portal',
#  'live video streaming app',
#  'local mobile os',
#  'location based app',
#  'location based engagement & rewards platform',
#  'location based nightlife recommendation\xa0 platform',
#  'logistics',
#  'logistics automation platform',
#  'logistics intelligence',
#  'logistics service platform',
#  'logistics service provider marketplace',
#  'logistics services provider',
#  'logistics solution provider',
#  'logistics tech',
#  'logistics tech platform',
#  'loyalty programs & reward points',
#  'luxury apparel rental',
#  'luxury goods\xa0 shopping platform',
#  'luxury rental homes',
#  'machine learning platform',
#  'marketing / advertising automation platform',
#  'marketplace app for bangkok',
#  'material collection & recycling',
#  'medical consultation & doctor appointment booking platform',
#  'medical tech instruments',
#  'micro finance platform',
#  'micro-brewery',
#  'mobile accessories online store',
#  'mobile advertising platform',
#  'mobile app based loan disbursement platform',
#  'mobile app development',
#  'mobile app testing platform',
#  'mobile application developer',
#  'mobile based pos solution',
#  'mobile car servicing appointment app',
#  'mobile chat based concierge service',
#  'mobile commerce for farmers',
#  'mobile commerce platform',
#  'mobile compression software',
#  'mobile fitness app',
#  'mobile fitness marketplace',
#  'mobile food ordering app',
#  'mobile game development & design platform',
#  'mobile growth hackingplatform',
#  'mobile health tech',
#  'mobile laundry cleaning service',
#  'mobile learning solutions',
#  'mobile marketing automation platform',
#  'mobile messaging assistant app',
#  'mobile only shopping assistant',
#  'mobile payment software platform',
#  'mobile payments app',
#  'mobile point of sale payment solution',
#  'mobile point of sale solutions',
#  'mobile services marketplace',
#  'mobile social network',
#  'mobile wallet',
#  'mobile-only tasks marketplace',
#  'modular furnishings marketplace',
#  'movie-on-demand platform',
#  'multi-sport program for preschoolers',
#  'multilingual test preparation platform',
#  'music streaming app',
#  'music streaming mobile app',
#  'mutual fund investing platform',
#  'new curation mobile app',
#  'news aggregator mobile app',
#  'nightlife discovery mobile app',
#  'non profit organization to alleviate poverty',
#  'nonbanking finance company',
#  'none',
#  'numerical computing & data science platform',
#  'off-grid solar power',
#  'offline tea chain',
#  'on demand beauty services platform',
#  'on demand cleaning & fixing services',
#  'on demand laundry service platform',
#  'on demand laundry services app',
#  'on demand mobile app developer',
#  'on-demand app based professional service provider',
#  'on-demand beauty service',
#  'on-demand beauty services',
#  'on-demand business messaging',
#  'on-demand car services app',
#  'on-demand delivery logistics',
#  'on-demand delivery service',
#  'on-demand handyman services',
#  'on-demand healthcare marketplace',
#  'on-demand home beauty and wellness portal',
#  'on-demand laundry & dry cleaning app',
#  'on-demand local logistics provider',
#  'on-demand logistics service',
#  'on-demand maids service provider',
#  'on-demand service marketplace',
#  'on-demand washing & dry-cleaning',
#  'ondemandmobile handyman services',
#  'online & mobile classified listings',
#  'online & mobile grocery store',
#  'online / mobile customer support',
#  'online and tv shopping marketplace',
#  'online apparels fashion brand',
#  'online art marketplace',
#  'online branded furniture etailer',
#  'online budget hotel booking service',
#  'online budget hotel chain',
#  'online bus & cab ticketing platform',
#  'online car portal',
#  'online car rental affiliates',
#  'online certification courses',
#  'online city & lifestyle guide',
#  'online classifieds',
#  'online classifieds & listings',
#  'online coffee delivery platform',
#  'online comparison engine',
#  'online consumer lending platform',
#  'online content platform for women',
#  'online counselling and psychological support platform',
#  'online coupon & comparison platform',
#  'online curated holiday package bookings',
#  'online diagnostic tests marketplace',
#  'online ed-tech platform',
#  'online education information platform',
#  'online education marketplace',
#  'online education platform',
#  'online fashion aggregator',
#  'online fashion video portal',
#  'online finance lending platform',
#  'online financial services',
#  'online food community platform',
#  'online food delivery',
#  'online food ordering',
#  'online food ordering & delivery',
#  'online food ordering & delivery platform',
#  'online food ordering & delivery service',
#  'online food ordering marketplace',
#  'online food-tech platform',
#  'online freight services aggregator',
#  'online furnishingecommerce',
#  'online furniture ecommerce',
#  'online furniture marketplace',
#  'online furniture, home appliances rental platform',
#  'online gourmet food marketplace',
#  'online grocer',
#  'online grocers',
#  'online grocery delivery',
#  'online grocery platform',
#  'online grocery store',
#  'online health & wellness platform',
#  'online hiring platform',
#  'online home décor',
#  'online home décor marketplace',
#  'online homeopathy clinic',
#  'online hotel booking',
#  'online identity verification services platform',
#  'online income tax filing platform',
#  'online insurance aggregator',
#  'online insurance distribution platform',
#  'online interior designing platform',
#  'online jewellery etailer',
#  'online jewellery store',
#  'online jewelry store',
#  'online job skills showcase',
#  'online kitchen furniture',
#  'online learning platform',
#  'online lending marketplace',
#  'online lingerie marketplace',
#  'online lingerie platform',
#  'online loans marketplace',
#  'online logistics platform',
#  'online marketplace',
#  'online marketplace for chef meals',
#  'online marketplace for industrial goods',
#  'online marketplace for photographers',
#  'online meal-booking platform for train travelers',
#  'online meat ordering platform',
#  'online media publication',
#  'online medical diagnostic',
#  'online movie review platform',
#  'online news media',
#  'online office rental',
#  'online p2p lending marketplace',
#  'online payment gateway',
#  'online pharmacy',
#  'online pharmacy & drug db',
#  'online policy aggregator',
#  'online printing marketplace',
#  'online printing services',
#  'online product comparison',
#  'online products discovery platform',
#  'online purchase rewards app',
#  'online real estate marketplace',
#  'online recipe sharing platform',
#  'online renting platform',
#  'online reputation management platform',
#  'online rti application services',
#  'online school for analytics learning',
#  'online security platform',
#  'online shopping assistant mobile app',
#  'online student & campus social networking platform',
#  'online study notes marketplace',
#  'online table reservation',
#  'online tailoring services',
#  'online taxi rental platform',
#  'online tiffin service aggregator',
#  'online travel marketplace',
#  'online travel planning',
#  'online user engagement platform',
#  'online vehicle spare parts etailer',
#  'online wedding marketplace',
#  'order fulfillment saas platform',
#  'organic food ecommerce',
#  'organic food etailer',
#  'others',
#  'p2p payments platform',
#  'p2p pre-owned goods marketplace',
#  'parents & kids online platform',
#  'parents focused web content',
#  'payment services platform',
#  'payment solutions platform',
#  'payments solution platform',
#  'payments solution provider',
#  'peer to peer lending platform',
#  'peer-to-peer money transfer & recharge app',
#  'performance based wholesale marketplace',
#  'performance optimization platform for athletes',
#  'personal diagnostic mobile app',
#  'personalized stock intelligence platform',
#  'personalized styling platform',
#  'personalized wish list creator app',
#  'photographer online search & booking platform',
#  'physical storage warehouses',
#  'picture based social app',
#  'picture creation & social mobile app',
#  'pre-owned games marketplace',
#  'pre-owned luxury online apparel seller',
#  'pre-school chain',
#  'pre-used apparel shopping mobile app',
#  'pre-used luxury item marketplace',
#  'premium apparel shopping portal',
#  'premium beverages',
#  'premium dining lounges & restaurants',
#  'premium loyalty rewards point management',
#  'prepaid bill manager app',
#  'prepaid mobile bill manager app',
#  'preventive healthcare services',
#  'price comparison',
#  'private cloud networks saas platform',
#  'private coaching centers',
#  'private jet bookings marketplace',
#  'private jet/ helicopter marketplace',
#  'private label apparel sales',
#  'private label fashion etailer',
#  'private label lingerie ecommerce',
#  'probiotic technology products manufacturer',
#  'product customization platform',
#  'product discovery & comparison app',
#  'product discovery & recommendation platform',
#  'product learning platform',
#  'professional custom creators marketplace',
#  'professional health services platform',
#  'professional service appointment booking service',
#  'professional services marketplace',
#  'professionals & project search marketplace',
#  'proximity marketing & mobile advertising platform',
#  'psychometric test online software',
#  'public commute helper app',
#  'qsr & online delivery portal',
#  'qsr chain',
#  'qsr restaurant chain',
#  'quick service restaurant & online delivery',
#  'quick service restaurant chain',
#  'rail ticket confirmation predictor',
#  'railways information mobile app',
#  'raw meat & ready to eat food etailer',
#  'ready to cook packaged foods',
#  'real estate',
#  'real estate advisory',
#  'real estate broker network app',
#  'real estate broker platform app',
#  'real estate focused tech platform',
#  'real estate insights platform',
#  'real estate intelligence platform',
#  'real estate mobile crm',
#  'real estate rating & analysis',
#  'real-time stock data platform',
#  'reality',
#  'renewable energy solutions',
#  'rental accommodation search platform',
#  'rental accomodation finder',
#  'residential rental management platform',
#  'restaurant customer engagement platform',
#  'restaurant discount app',
#  'restaurant management platform',
#  'restaurant ratings & reviews platform',
#  'restaurant reservation app',
#  'restaurant reservation platform',
#  'restaurant reviews',
#  'reward points mobile app',
#  'ride sharing platform',
#  'ridesharing mobile app',
#  'robotic program learning',
#  'rooftop solar plants',
#  'saas product intelligence platform',
#  'sales & productivity software',
#  'science learning app',
#  'scientific horoscope online assistance platform',
#  'self driven car rental',
#  'self driven rental car platform',
#  'self-driven car rental',
#  'self-driven vehicle rental',
#  'self-storage spaces',
#  'selfie mobile app',
#  'service-on-demand mobile app',
#  'skill training & placement platform',
#  'skill training startup',
#  'small business financing (nbfc)',
#  'smart report cards for schools',
#  'smart safety wearable devices',
#  'smartwatch maker',
#  'social fitness platform',
#  'social learning platform',
#  'social network for artists',
#  'social platform for traders and investors',
#  'solar power solutions company',
#  'solar products and services marketplace',
#  'spa & salon management software',
#  'spam call block app',
#  'speech recognition solutions',
#  'splitting bills mobile app',
#  'sports education platform',
#  'sports management & physical education business',
#  'startup analytics platform',
#  'startup focused online publisher',
#  'startup funding marketplace',
#  'startup funding platform',
#  'stock market portal',
#  'structural & civil engg service automation',
#  'study material marketplace',
#  'subscription based online grocery platform',
#  'supply chain & logistics solutions',
#  'sustainable agri-inputs firm',
#  'talent exchange & talent services marketplace',
#  'talent platform for fashion professionals',
#  'taxi rental platform',
#  'teacher empowerment platform',
#  'tech enabled ac bus service',
#  'tech enabled logistics platform',
#  'tech platform for property brokers',
#  'tech recruitment platform',
#  'tech-enabled learning',
#  'tech-enabled rural healthcare services',
#  'technology',
#  'tele-shopping / ecommerce',
#  'test automation saas platform',
#  'transportation & logistics platform',
#  'travel community platform',
#  'travel destination discovery platform',
#  'travel entertainment',
#  'travel guide mobile app',
#  'travel information portal',
#  'travel search engine',
#  'travel tech',
#  'truck aggregator & logistics service',
#  'trucking logistic operations',
#  'two-wheeler taxi service',
#  'used bikes marketplace',
#  'used car marketplace',
#  'used gadgets buy / refurbishing',
#  'used two-wheeler marketplace',
#  'used vehicle marketplace',
#  'used vehicles marketplace',
#  'user engagment & analytics platform',
#  'video advertisement platform',
#  'video intelligence platform',
#  'video streaming',
#  'viral content web platform',
#  'virtual health consultation app',
#  'virtual reality activity based learning platform',
#  'virtual reality headset creator',
#  'virtual reality, 3d simulation and stereoscopic products',
#  'visual blogging platform',
#  'visual search and discovery platform',
#  'voice call incentivization mobile app',
#  'warranty programs service administration',
#  'waste management solutions',
#  'wealth management platform',
#  'web content publishing',
#  'wedding planning platform',
#  'wedding venues & vendors marketplace',
#  'weight management service',
#  'wifi – first cloud communication platform',
#  'women ethnic wear\xa0 online marketplace',
#  'women lifestyle marketplace',
#  'womens fashion wear portal',
#  'workforce management software']

# %% [markdown]
# # Top Investor

# %%
from collections import Counter
import pandas as pd
import operator
data = pd.read_csv('startup_funding.csv', skipinitialspace=True)

# Empty values fill
data['AmountInUSD'] = data['AmountInUSD'].fillna('0,0')
data = data.fillna('None')

data = data.sort_values('InvestorsName')
Counter(data['InvestorsName'])
# Out:
# Counter({'1Crowd': 1,
#          '1Crowd (through crowd funding)': 1,
#          '1Crowd (through crowdfunding)': 1,
#          '1Crowd, Eureka Forbes Ltd, Shapoorji Pallonji & Co. Ltd.': 1,
#          '3 undisclosed HNIs': 1,
#          '3 undisclosed investors': 1,
#          '3One4 Capital': 1,
#          '3one4 Capital, Mumbai Angels, Aarin Capital': 1,
#          '3one4 Capital, Tracxn Labs, Aaruha Technology Fund, Endiya Partners': 1,
#          '3one4 capital': 1,
#          '500 Startups': 3,
#          '500 Startups, IDG Ventures & Advantedge fund, Neeraj Arora, Leon Seynave': 1,
#          '500 Startups, IvyCap Ventures': 1,
#          '500 Startups, Littlerock, Singularity Ventures': 1,
#          '500 Startups, Mato Peric & Others': 1,
#          '500 Startups, Mato Peric, TracxnLabs': 1,
#          '500 Startups, Purvi Capital, Rajan Anandan, Abhishek Gupta': 1,
#          '500 Startups, Smile Multimedia, Kunal Bahl, Rohit Bansal, Girish Matrubootham': 1,
#          '500 Startups, TV Mohandas Pai, Tandem Capital, Vikram Chachra, Aloke Bajpai': 1,
#          '50K Ventures': 3,
#          '50k Ventures, Munish Jauhar, Pulkit Jain, Rohit Narang': 1,
#          '91maker.com': 1,
#          'A M Sikander': 1,
#          'AB Kinnevik, Falcon Edge Capital, Coatue Management': 1,
#          'ABI-Showatech (India) Ltd': 1,
#          'ABM Knowledgeware': 1,
#          'ADAG Reliance Private Equity': 1,
#          'ANALEC': 1,
#          'APIS Partners': 1,
#          'ASK Pravi': 1,
#          'AVG Group, 500 Startups': 1,
#          'Aakrit Vaish, Swapan Rajdev, Sushill Jiwarajka': 1,
#          'Aarin Capital': 1,
#          'Aarin Capital Partners': 2,
#          'Aarin Capital Partners,': 1,
#          'Aarin Capital Partners, TV Mohandas Pai': 1,
#          'Aarin Capital, Michael Herzig, Ashish Lakhanpal': 1,
#          'Aarin Capital, Unitus Seed Fund': 1,
#          'Aarti Group': 1,
#          'Aavishkaar': 2,
#          'Aavishkaar Venture Management': 1,
#          'Aavya Ventures': 1,
#          'Abhijit Avasthi, Karan Chellani, SP Vijay': 1,
#          'Abhinav Bindra, Gaurav Marya': 1,
#          'Abhinav Mathur': 1,
#          'Abhishek Agarwal, Krishnakumar Nataraj, Sarath Sura, Shanti Mohan, Sarthak and Nihit Agarwal, Suramya Gupta': 1,
#          'Abhishek Gupta': 1,
#          'Abraaj Group': 1,
#          'Accel Partner, Jungle Ventures': 1,
#          'Accel Partners': 9,
#          'Accel Partners India': 2,
#          'Accel Partners India, RB Investments': 1,
#          'Accel Partners, Anupam Mittal & other marquee investors': 1,
#          'Accel Partners, Ashish Hemrajani, Parikshit Dar, Rajesh Balpande': 1,
#          'Accel Partners, Beenext, Powerhouse Ventures, Akusa Holdings': 1,
#          'Accel Partners, Deep Kalra, Rajesh Magow, Mohit Gupta, Shamik Sharma': 1,
#          'Accel Partners, Elevar Equity, Pramod Bhasin, Rajan Anandan, Gaurav Dalmia, Abhishek Goyal, Gagan Hasteer , Arun Tadanki': 1,
#          'Accel Partners, Flipkart': 1,
#          'Accel Partners, Helion Venture Partners': 2,
#          'Accel Partners, IDG Ventures India': 1,
#          'Accel Partners, IDG Ventures, Endiya Partners, pi Ventures, VH Capital, Axilor Partners': 1,
#          'Accel Partners, IDG Ventures, Kalaari Capital': 1,
#          'Accel Partners, Indian Angel Network, India Innovation Fund India Venture Partners': 1,
#          'Accel Partners, International Finance Corporation (IFC), Qualcomm Ventures, Ventureast': 1,
#          'Accel Partners, Jungle Ventures, SeedPlus': 1,
#          'Accel Partners, Kalaari Capital': 1,
#          'Accel Partners, Matrix Partners, Girish Mathrubootham': 1,
#          'Accel Partners, Nandan Nilekani,': 1,
#          'Accel Partners, Nandan Nilekani’s NRJN Trust, Mistletoe, Qualcomm Ventures, M&S Partners': 1,
#          'Accel Partners, Qualcomm Ventures, M&S Partners, Zop Smart': 1,
#          'Accel Partners, RB Investments': 1,
#          'Accel Partners, SAIF Partners': 1,
#          'Accel Partners, Shunwei Capital': 1,
#          'Accel Partners, Subrata Mitra, Larry Braitman, Venk Krishna': 1,
#          'Accel Partners, Tiger Global Management': 1,
#          'Accel Partners, Traxcn Labs & Others': 1,
#          'Accel US, Accel India, SAIF Partners.': 1,
#          'Accion Venture Labs, Rianta Capital': 1,
#          'Accion, LeapFrog Investments, Lok Capital': 1,
#          'Acumen Fund': 3,
#          'Adroitent Pvt. Ltd.': 1,
#          'Agarwal Movers Group': 1,
#          'Agnus Capital': 2,
#          'Agnus Capital, Khattar Holdings': 1,
#          'Ah! Ventures, Calcutta Angels,\xa0 91SpringBoard': 1,
#          'Ajai Chowdhry, Ashvin Chadha, Yogesh Bansal,Nitin Singhal & Others': 1,
#          'Ajay Data & other HNIs': 1,
#          'Ajay Data & undisclosed HNIs': 1,
#          'Ajay Nanavati, Afsal Salu': 1,
#          'Ajay Piramal': 1,
#          'Ajay Relan': 1,
#          'Ajay Relan,': 1,
#          'Ajay Relan, LetsVenture': 1,
#          'Ajeet Khurana & Others': 1,
#          'Ajeet Khurana Jinesh Shah, Vikram Chachra, Dr. Aniruddha Malpani': 1,
#          'Ajit Surana, Sanjay Mehta': 1,
#          'Ajith Nair': 1,
#          'Ajith Nair, Anish K': 1,
#          'Ajith Sukumaran, Currae Healthtech Fund': 1,
#          'Ajmera Group of Companies': 1,
#          'Al Dhaheri family': 1,
#          'Alex Chua, Rahul Garg': 1,
#          'Alex Kuruvilla, Pradeep Guha, Saket Dhankar, Rajan Pandhare': 1,
#          'Alibaba': 1,
#          'Alibaba Group, Ant Financial': 1,
#          'Alibaba Pictures': 1,
#          'Alibaba, Foxconn, Softbank': 1,
#          'Allen Blue, John Katzman, Naveen Tewari, Kartik Hosanagar, Kashyap Deorah, 500 Startups, Blue Fog Capital': 1,
#          'Alok Bajpai, Rajnish Kumar, Amit Dey': 1,
#          'Alok Goel': 1,
#          'Alok Mittal': 1,
#          'Alok Mittal, Amit Gupta, Anuj Srivastava, Himanshu Aggarwal, Raghunandan G, Puneet Agarwal': 1,
#          'Alok Mittal, Zeeshan Hayat, Niraj Singh, Nikunj Jain, Anirudh Damani, Punit Goyal': 1,
#          'Alok Rawat, Grey Orange Robotics': 1,
#          'Alpha Capital': 1,
#          'Alphard Maritime Group': 1,
#          'Amadeus Capital': 1,
#          'Amajit Gupta, Praveen Dubey, J.P. Bhatt': 1,
#          'Amazon, Fidelity Growth Partners, Mousse Partners': 1,
#          'Amazon, Vertex Ventures, Qualcomm, Ru-Net Technology Partners, Matrix Partners': 1,
#          'Ambit Pragma': 1,
#          'Ameera Shah, Vivek Bhargava': 1,
#          'Amen Dhyllon': 1,
#          'American Express Ventures, Sequoia Capital': 1,
#          'Amit Choudhary': 1,
#          'Amit Choudhary, Anuj Puri': 1,
#          'Amit Gupta, Sahil Barua, Mukul Singhal, Tracxn Labs': 1,
#          'Amit Patni, Anirudh Damani, Samir Shah': 1,
#          'Amit Ranjan, Deepinder Goyal, Zishaan Hayath, Powai Lake Ventures': 1,
#          'Amit Ranjan, Vijay Shekhar Sharma, Kunal Bahl, Girish Mathrubootham &\xa0 Group of other Angel investors': 1,
#          'Amit Singhal, PK Gulati & others': 1,
#          'Amit Tyagi, Sandeep Acharya & others': 1,
#          'Amod Malviya': 1,
#          'Anand Chandrasekaran': 3,
#          'Anand Chandrasekaran & Others': 1,
#          'Anand Chandrasekaran, Ananth Narayanan, Mekin Maheshwari, Ravi Garikipati, Divyesh Shah, Swastika Company Ltd': 1,
#          'Anand Chandrasekaran, Kanwaljit Singh, Manoj Varghese': 1,
#          'Anand Chandrasekaran, Rajesh Sawhney, Kalpana Tatavarti, Shivanandan Pare': 1,
#          'Anand Chandrasekaran, Rajiv Mehta, Ramakant Sharma': 1,
#          'Anand Mahindra': 2,
#          'Anand Mahindra, Uday Punj, Ashish Hemrajani, Sanjeev Mehra': 1,
#          'Anand Rajaraman, Venky Harinarayan': 1,
#          'Anand Sankeshwar, Yang Shu': 1,
#          'Anand Vijay, Nipun Dureja, Satyajit Heeralal, Keith Rodricks, Gaurav Lochan, Azmul Haque, Nikhil Bagri': 1,
#          'Anand Vijay, Shashank Mehrotra & Others': 1,
#          'Aneesh Seth, Tushar Mittal': 1,
#          'AngelPrime': 3,
#          'Anglian Omega Network': 2,
#          'Anicut Capital': 1,
#          'Anil Jain & other HNIs': 1,
#          'Anil Kapoor': 1,
#          'Anil Matai, Vikram Tandon, Shyam Sundar R & others': 1,
#          'Anil Menon': 1,
#          'Anirudh Damani, Daud Ali, Narendra Karnavat, Vikas Kapoor, Vikram Lakhotia, Krishna Jhunjhunwaala, Jayesh Shah': 1,
#          'Anirudh Damani, Vikram Lakhotia': 1,
#          'Anita Dongre, Yash Dongre, Milind Sarwate': 1,
#          'Ankit Gupta, Puneet Motihar': 1,
#          'Ankit Maheshwari, Anand Singh': 1,
#          'Ankit Nagori': 1,
#          'Ankur Capital, Hyderabad Angels': 1,
#          'Ankur Gupta': 1,
#          'Ankush Mehta': 1,
#          'Ankush Nijhawan, Manish Dhingra, Gaurav Bhatnagar': 1,
#          'Ant Financial Services (Alipay)': 1,
#          'Anupam Mittal, Amit Gupta, Utsav Somani, Neeraj Goenka, Farooq Adam Mukadam': 1,
#          'Anupam Mittal, Anand Chandrasekaran, Uday Shankar, Chetan Bhagat': 1,
#          'Anupam Mittal, Anuj Srivastava, Ankit Nagori': 1,
#          'Anupam Mittal, Manish Vij, Prashant Tandon, Gaurav Agarwal, Akash Agarwal, Himanshu Aggarwal, Kevin Parikh': 1,
#          'Anupam Mittal, Sharad Sharma & 14 others': 1,
#          'Anurag Chauhan': 1,
#          'Aparup Sengupta, Devendra Reddy,': 1,
#          'Apoorv Ranjan Sharma, Daud Ali and others': 1,
#          'Applyifi': 1,
#          'Aprameya Radhakrishna': 1,
#          'Aprameya Radhakrishna, Deepak Natraj, Girish Mathrubootham, Mahesh Murthy, Pallav Nadhani, Pavan Ongole, Sandeep Mathur, Vijay Shekhar Sharma & Others': 1,
#          'Aprameya Radhakrishna, Naman Sarawagi, Afsal Salu,': 1,
#          'Aqeel Ahmed': 1,
#          'Aramex Ventures Llc': 1,
#          'Arihant Patni, Avnish Mehra, Pranay Adhvaryu, Ravi Sampat': 1,
#          'Arihant Patni, RAAY Global Investments': 1,
#          'Arihant Patni, Vishal Khare,\xa0 Viswanath Ramachandran': 1,
#          'Arjun Handa, Amit Jindal, Nagendra Chaudhary': 1,
#          'Armat Group': 1,
#          'Artha India Ventures, Singularity Holdings, Rajan Anandan, Girish Mathrubootham': 1,
#          'Artiman Ventures': 1,
#          'Arun Chandra Mohan': 1,
#          'Arun Chandra Mohan, Praveen Sinha': 1,
#          'Arun Patodia, Bharat Kedia': 1,
#          'Arun Seth, T.V. Mohandas Pai, Anand Chandrasekaran, Deepak Ghaisas': 1,
#          'Arun Tadanki, Aditya Verma': 1,
#          'Ascent Capital, Kalaari Capital': 1,
#          'Ash Bhardwaj': 1,
#          'Asha Jadeja Motwani & Others': 1,
#          'Ashish Gupta': 2,
#          'Ashish Gupta and other undisclosed investors': 1,
#          'Ashish Jhalani': 1,
#          'Ashish Mahajan, Sarvesh Sharma': 1,
#          'Ashish Todi, Abhinav Patodia, Kumar Shwetabh': 1,
#          'Ashok Agarwal': 1,
#          'Ashok Goel (promoter)': 1,
#          'Ashutosh Lawania, Alok Goel & others': 1,
#          'Ashutosh Lawania, Rajul Jain, Badal Malick, Rishi Gupta & Others': 1,
#          'Ashvin Chadha': 1,
#          'Ashvin Chadha, Avtar Monga, Udaan Angels, Dheeraj Jain': 1,
#          'Asia Pacific Internet Group': 1,
#          'AskMe': 1,
#          'Aspada Advisors, IDG Ventures,\xa0 Inventus Capital': 1,
#          'Aspada Investment Advisors, Blume Ventures.': 1,
#          'Aspada Investment Advisors, Qualcomm Ventures': 1,
#          'Aspada Investments': 1,
#          'Aspire Systems': 1,
#          'Asset Management (Asia) Ltd, Digital Garage Inc': 1,
#          'Astarc Ventures': 1,
#          'Astarc Ventures & Others': 1,
#          'Astarc Ventures, 50K Ventures & others': 1,
#          'Astarc Ventures, Anand Chandrasekaran': 1,
#          'Asuka Holdings': 1,
#          'Asuka Holdings, YouWeCan Ventures, Beenext, Beenos, M&S Partners': 1,
#          'Asuka, Pravega Ventures, BEENEXT': 1,
#          'Atul Ingle': 1,
#          'Atul Jain, Anil Gelra, Jaikumar Nair': 1,
#          'Atul Jalan': 1,
#          'Atul Jalan, Shrikanth & Bharath': 1,
#          'Atul Nishar': 1,
#          'Atulya Mittal': 1,
#          'Augment Ventures, Rahul Kayan, Nikhil Golcha, Shubham Gupta, Roy Kwan': 1,
#          'August Capital Partners, Michael Blakey': 1,
#          'Axiata Digital': 1,
#          'Axilor Ventures': 4,
#          'Axilor Ventures, Parampara Early Stage Opportunities Fund & Others': 1,
#          'Axilor, undisclosed investors': 1,
#          'Ayesha Takia Azmi, Abu Farhan Azmi': 1,
#          'B Capital Group, Ignition Partners, Greycroft, e.ventures,\xa0 Eight Roads Ventures': 1,
#          'B M Gupta, Vinod Singhal': 1,
#          'B S Nagesh': 1,
#          'BCCL': 1,
#          'BEENEXT': 1,
#          'BLIP Initiatives': 1,
#          'Baillie Gifford, Falcon Edge Capital, Tiger Global, SoftBank Group, DST Global, Didi Kuaidi': 1,
#          'Balasubramanian Krishnamurthy, Sidhartha Hazarika & Others': 1,
#          'Batlivala & Karani Securities, Venture Works': 1,
#          'BedRock Ventures, Rajesh Sawhney, Shailesh Singh': 1,
#          'Bedrock Ventures': 1,
#          'BeeNext, TV Mohandas Pai, Kunal Shah, Sandeep Tandon': 1,
#          'Beenext': 1,
#          'Beenext, Digital Garage, Beenos, Qualgro, Mamoru Taniya, SAIF Partners': 1,
#          'Beenext, Digital Garage, Lightbox, Beenos': 1,
#          'Beerud Sheth and Ravi Mantha': 1,
#          'Bennett, Coleman and Co. Ltd (BCCL)': 1,
#          'Bennett, Coleman and Company Ltd': 2,
#          'Benori Ventures LLP': 1,
#          'Bertelsmann India': 1,
#          'Bertelsmann India Investments': 1,
#          'Bertelsmann India Investments, Mayfield India, Saama Capital, India Quotient': 1,
#          'Bertelsmann India Investments, Nirvana Digital India Fund, Nirvana Digital Investment Holding, 500 Startups': 1,
#          'Bessemer Venture Partner, Accel, SAIF Partners': 1,
#          'Bessemer Venture Partners': 5,
#          'Bessemer Venture Partners, Anil Chopra': 1,
#          'Bessemer Venture Partners, Jungle Ventures, Helion Ventures': 1,
#          'Bessemer Venture Partners, Orios Venture Partners, Trifecta Capital,': 1,
#          'Bessemer Venture Partners, SAIF Partners': 1,
#          'Bessemer Venture Partners, Stellaris Venture Partners, Jungle Venture Partners, Axis Capital': 1,
#          'Bessemer Ventures, Blume Ventures': 1,
#          'Bessemer Ventures, Kae Capital': 1,
#          'Best Foodworks': 1,
#          'BetOnIndia Technology Pvt Ltd': 1,
#          'Bhanu Vikram Parsotam, Rohan Desai and Paras Patel': 1,
#          'Bharanidharan Viswanathan, Sanjiv Mittal, Shobhit Shukla, Rahul Agarwal': 1,
#          'Bhavdeep Reddy': 1,
#          'Bhavin Turakhia': 1,
#          'Bhavish Aggarwal, Ankit Bhati': 1,
#          'Bhavish Aggarwal, Binny Bansal,\xa0 Rajan Anandan, Mekin Maheshwar, Sunil Kalra, Anupam Mittal, Krishna Mehra, Singapore Angel Network': 1,
#          'Bhupen Shah, Jayesh Parekh, Sanjay Sathe': 1,
#          'Binny Bansal, Anupam Mittal, Sachin Bhatia, Darius Pandole, Kunal Khattar, Dheerag Jain': 1,
#          'BitChemy Ventures, Maheshwari Investments Pvt Ltd, Anshoo Gaur, Rama Krishna Reddy, Sandeep Seerapu': 1,
#          'Bitkemy Ventures': 1,
#          'Biz Stone': 1,
#          'BlackJag Partners': 1,
#          'BlackSoil Capital Pvt Ltd': 1,
#          'BlackSoil Capital Pvt. Ltd': 1,
#          'BlackSoil Capital Pvt. Ltd.': 1,
#          'Blacksoil Capital Pvt. Ltd': 1,
#          'Blackstone Valley Group, Raghu Vohra, Aditya Dev Sood, Kamal Bansal': 1,
#          'Blinc Advisors, Amit Nanavati, Tashwinder Singh, Taranjit Jaswal, Amit Khanna': 1,
#          'Blue Orchard': 1,
#          'Blume Ventures': 6,
#          'Blume Ventures & Other unnamed Investors': 1,
#          'Blume Ventures & Others': 1,
#          'Blume Ventures, Adil Allana, Aprameya Radhakrishna, Gautam Ivatury, Signal Point Partners': 1,
#          'Blume Ventures, BEENEXT, Barkawi Holdings GmbH, TM Service Technology Holdings Gmbh, Sreevathsa Prabhakar': 1,
#          'Blume Ventures, Barkawi Holdings GmbH, TM Service Technology Holdings GmbH': 1,
#          'Blume Ventures, Contrarian Capital India Partners, Emergent Ventures India, Pallav Nadhani, Ashish Gupta, Sharad Sharma, Sirion Labs': 1,
#          'Blume Ventures, Contrarian Capital, 91springboard, Emergent Ventures, Abstract Ventures, Anthill Ventures, Axilor Ventures': 1,
#          'Blume Ventures, Flipkart': 1,
#          'Blume Ventures, Girish Mathrubootham, Aprameya Radhakrishna': 1,
#          'Blume Ventures, Indian Angel Network, Kunal Shah, Sandeep Tandon': 1,
#          'Blume Ventures, Mumbai Angels, ah! Ventures, Digital Currency Group, Boost VC, Bank to the Future and Funders Club': 1,
#          'Blume Ventures, NB Ventures, Nspira': 1,
#          'Blume Ventures, Rajan Anandan, Sumit Jain, Aprameya Radhakrishna, Sujeet Kumar, Phanindra Sama': 1,
#          'Blume Ventures, Sachin Bansal, Vijay Shekhar Sharma, Binny Bansal,\xa0 Kunal Shah, Sandeep Tandon, Ashish Tulsian': 1,
#          'Blume Ventures,\xa0 Tracxn Labs': 1,
#          'Bodhtree Consulting Limited': 1,
#          'Boman Irani, Dhruv Chitgopekar, Prantik Dasgupta': 1,
#          'BookMyShow': 1,
#          'Brand Capital': 10,
#          'Brand Capital, Paragon Trust': 1,
#          'Brand Capital, Siddhivinayak Skyscrapers, Dinesh R. Challa': 1,
#          'Bravia Capital': 1,
#          'Bren Corporation': 1,
#          'Brian Acton': 1,
#          'Brick Eagle': 1,
#          'Brigade Innovations LLP, TV Mohandas Pai, Suhail Rahman, Bobby Reddy, M George Oommen': 1,
#          'Broadbean Capital services': 1,
#          'ByteDance, Arun Sarin, Matrix Partners, Sequoia Capital India, Omidyar Network,\xa0 Falcon Edge': 1,
#          'CA Media LP,\xa0 Start Media.': 1,
#          'CASHurDRIVE Marketing Pvt Ltd': 1,
#          'CCube Angels, Frontline Strategy': 1,
#          'CDC Group Plc': 1,
#          'CIO Angel Network': 2,
#          'CIO Angel Network (CAN)': 1,
#          'CIO Angel Network, Indian Angel Network': 1,
#          'CLSA Capital Partners ARIA IV Funds': 1,
#          'CMYK Health Boutique Pvt Ltd & Other individual investors': 1,
#          'CP Bothra': 1,
#          'Calcutta Angel Network, Appliyifi': 1,
#          'Calcutta Angels Network': 1,
#          'Calcutta Angels Network (CAN), Augment Ventures': 1,
#          'Calcutta Angels Network, LetsVenture, Anupam Mittal, Currae Healthtech Fund': 1,
#          'Calcutta Angels, Lead Angels & Others': 1,
#          'Calcutta Angels, Venture Nursery Angels Mumbai Angels': 1,
#          'Cameron Jones': 1,
#          'Cao Yibin, Huang Wei, Madhusudan E,': 1,
#          'CapitalG, Sequoia India': 1,
#          'CareerNet Consulting Pvt. Ltd, Ideation Initiative Pvt. Ltd,': 1,
#          'Carlyle Group, Tiger Global': 1,
#          'Carpediem Capital': 2,
#          'Carpediem Capital & Others': 1,
#          'Carrick Capital Partners': 1,
#          'Catamaran Ventures, New India Investment Corporation': 1,
#          'Cataraman Ventures': 1,
#          'Centre For Incubation & Business Acceleration (CIBA), Goa': 1,
#          'Centre for Innovation Incubation and Entrepreneurship (CIIE)': 3,
#          'CerraCap': 1,
#          'Chan Zuckerberg Initiative, Times Internet Ltd, Sequoia Capital, Sofina, Lightspeed Ventures': 1,
#          'Chandigarh Angel Network (CAN)': 1,
#          'Chandigarh Angels Funding': 1,
#          'Chandigarh Angels Network': 2,
#          'Chandigarh Angels Network (CAN)': 1,
#          'Chandigarh Angels Network, Social Alpha and other unnamed angel investors': 1,
#          'Chandigarh Angels, Ashish Gupta, Rohit, Ashish Chand, Sunil Singh & Others': 1,
#          'Chandralekha Construction Pvt. Ltd.': 1,
#          'Chandrashekar Tallapragada, Pankaj Kapoor': 1,
#          'Chatsworth Management, ITW Digital': 1,
#          'Chennai Angels': 3,
#          'Chennai Angels, Calcutta Angels, ah! Ventures, Intellecap Impact Investment Network, Indus Age Partners, Singapore Angel Network, India Internet Fund, LetsVenture': 1,
#          'Chicago Capital Ventures, Sanjay Mehta, Others': 1,
#          'Chip Perry': 1,
#          'Chirag Nikunj Sheth & Others': 1,
#          'ChrysCapital': 1,
#          'Cipher-Plexus Capital Advisors & Indian HNIs': 1,
#          'Clairvest Group': 1,
#          'CoCreate Ventures': 1,
#          'Cogent E Services': 1,
#          'Collaborative Licensing Ventures LLP': 1,
#          'Commonfloor': 1,
#          'Concur Technologies, Gund Investment': 1,
#          'Consortium of Angel Investors': 1,
#          'Constellation Technology Ventures (Exelon Corporation), E.ON, RWE, Khosla Ventures': 1,
#          'Corvus Ventures, MAPE Advisory Group': 1,
#          'Creation Investments Capital Management, SAIF Partners, Sequoia Capital, Aspada Ventures': 1,
#          'Cross Border Angels': 1,
#          'Cross Border Angels & Experts': 1,
#          'Cross Border Angels & Experts, Rajasthan Angel Innovators Network, The Chennai Angels': 1,
#          'Cross Border Angels & others': 1,
#          'Ctrip.com International Ltd': 1,
#          'CureFit': 1,
#          'Currae Healthtech Fund, Unicorn India Ventures': 1,
#          'Cyber Carrier': 1,
#          'Cyber Carrier CL': 1,
#          'DA-IICT, Techstars, Carnegie Mellon University, Startup Brasil program': 1,
#          'DAH Beteiligungs GmbH': 1,
#          'DG Ventures India, Dewan Housing Finance Corp': 1,
#          'DHI Group Inc, Prime Venture Partners, Beenext, Beenos, Digital Garage, BizReach': 1,
#          'DMG Information': 1,
#          'DMG information Asia Pacific': 1,
#          'DSG Consumer Partners': 2,
#          'DSG Consumer Partners, American Express Ventures, Cyber Carrier VC, AdvantEdge Partners': 1,
#          'DSG Consumer Partners, Saama Capital': 1,
#          'DSG Consumer Partners, Saama Capital.': 1,
#          'DSG Consumer Partners, Siddharth Parekh': 1,
#          'DSG consumer Partners, Paragon Partners': 1,
#          'DST Global, Steadview Capital, Tiger Global, Accel Partners & Others': 1,
#          'DTDC Express Ltd': 1,
#          'Daljit Singh, Dr. Pramath Raj Sinha, BVR Mohan Reddy': 1,
#          'Daman Soni, Rajat Gupta & Others': 1,
#          'DanGold Investment Corp': 1,
#          'DeNA Co., Japan & Teruhide Sato (in Addition to MKS Switzerland & Kris GopalKrishnan)': 1,
#          'Deep Kalra, Sequoia Capital, Omidyar Network, Intel Capital & Kae Capital': 1,
#          'Deepak Gupta': 1,
#          'Deepak Gurnani': 1,
#          'Deepak Kulkarni, Sandeep Pangal': 1,
#          'Deepak Nathani': 3,
#          'Deepak Shahdadpuri, Gulpreet Kohli': 1,
#          'Delhivery': 1,
#          'Delhivery, Sands Capital and Accel Partners': 1,
#          'Delhivery, Tracxn Labs': 1,
#          'Delta Partners, Sequoia India,\xa0 Mayfield, Blacksoil, Trifecta Capital': 1,
#          'Deutsche Telekom Strategic Investments & Others': 1,
#          'Devdeep Singh': 1,
#          'Development finance institution Belgian Investment Company, Oikocredit': 1,
#          'Devesh Rai G, Rajesh Aggarwal, Amitpal Bhutani': 1,
#          'Devesh Sachdev, Ashish Tiwari': 1,
#          'Devidas Desai, Vipul Gautam, Singapore Angel Network': 1,
#          'Dewang Neralla,Roopak Taneja, Manisha Gupta': 1,
#          'Dheeraj Jain & Other angel investors': 1,
#          'Dheeraj Jain & Others': 1,
#          'Dheeraj Jain, Jagdish Kumar, Bharat Gupta, Ankush Saigal, Praveen Saini': 1,
#          'Dheeraj Jain, Palash Jain, Anupam Mittal, Ameera Shah,\xa0 Vivek Bhargava, Rahul Singh, Ambarish Gupta,': 1,
#          'Dheeraj Pandey, Rajesh Yohannan, Akash Garg': 1,
#          'Didi Kuaidi': 1,
#          'Digital Financial Service Lab': 1,
#          'Dileep Bhatt, Milind Chaudhary': 1,
#          'Dinesh Agarwal': 2,
#          'Dino Morea': 1,
#          'Dr David Cheriton': 1,
#          'Dr Mushtaq Shah, Dr Faraz Naqvi': 1,
#          'Dr Nandish Domlur, Amit Sandill': 1,
#          'Dr Ramesh Ayyala, Satya Muthyala': 1,
#          'Dr. Abhishek Pandey, Jaysukh Sapra': 1,
#          'Dr. Aniruddha Malpani': 1,
#          'Dr. Aniruddha Malpani Manish Gupta, M&S Partners & others': 1,
#          'Dr. Apoorv Ranjan Sharma, Anil Jain, Anuj Golecha, Krishna Jhunjhunwala, Anirudh Damani': 1,
#          'Dr. Goutam Challagalla': 1,
#          'Dr. Pooja Gandhi': 1,
#          'Dr. Rameshwar Kumar': 1,
#          'Dr. Ritesh Malik': 1,
#          'Dr. Sridhar Ramaswamy, Rakesh Mathur': 1,
#          'Dragoneer Investment, Accel Partners, Qualcomm Ventures, Times Internet': 1,
#          'Dream Incubator': 1,
#          'Dunamis Ventures Pte Ltd': 1,
#          'Dunamis Ventures Pte Ltd.': 1,
#          'Dutch government fund': 1,
#          'EVC Ventures': 2,
#          'Eagle10 Ventures': 1,
#          'Earlsfield Capital': 2,
#          'Earlsfield Capital, Sailender Solanki, Rajiv Solanki': 1,
#          'East Ventures & Others': 1,
#          'Edelweiss Financial Services': 1,
#          'Edelweiss Private Equity': 3,
#          'Eduardo Saverin': 1,
#          'Eduardo Saverin & Velos Capital': 1,
#          'Eight Road Ventures': 1,
#          'Eight Roads Ventures': 4,
#          'Elliot Stechman, Gautam Sinha, Ambarish Ray': 1,
#          'Emerald Media': 1,
#          'Emerald Media, Premji Invest': 1,
#          'Emerging India': 1,
#          'Enablers platform': 1,
#          'Endiya Partners': 1,
#          'Endiya Partners, Mekin Maheshwari, Rajesh Sawhney': 1,
#          'Endiya Partners, Ventureast': 1,
#          'Ennovent Impact Investment Holding': 1,
#          'Epsilon Venture Partners': 1,
#          'Equentia Natural Resource & Other undisclosed investors': 1,
#          'Equentia Natural Resources': 1,
#          'Equity Crest, Vinners, Sparknext': 1,
#          'Eros Labs': 2,
#          'Exfinity Fund, GrowX Ventures.': 1,
#          'Exfinity Venture Partners': 4,
#          'Exfinity Venture Partners, Blume Ventures, BeeNext, Rajesh Ranavat': 1,
#          'Exfinity Venture Partners, Unitus Impact Livelihoods Fund': 1,
#          'Exfinity Ventures': 1,
#          'Existing & New Investors': 1,
#          'Existing Investors': 1,
#          'Extreme Venture Partners\xa0 William Bissell': 1,
#          'FF Angel, Sequoia Capital': 1,
#          'FIH Mobile Ltd': 1,
#          'FTV Capital, Zodius Capital': 1,
#          'Facebook FB Start programme': 1,
#          'Facebook FBStart': 3,
#          'Faering Capital, Foundation Capital, Inventus Capital Partners': 1,
#          'Fairfax Holdings': 1,
#          'Falcon Edge Capital, Matrix Partners India, Sequoia Capital India and Omidyar Network': 1,
#          'Falcon Edge Capital, Meru Capital, Ola, Matrix Partners, DSG Consumer Partners, Axis Bank': 1,
#          'Falcon Edge Capital, NY based Hedge Fund, Tiger Global, Softbank': 1,
#          'Falcon Edge Capital,\xa0 Capital Advisers': 1,
#          'Farooq Adam, Ambi Parameswaran,': 1,
#          'Farooq Oomerbhoy & Other angel investors': 1,
#          'Farooq Oomerbhoy, Anupam Mittal, Anand Mittal, Ravi Garikipati, Vibhu Garg, Singapore Angel Network, Konglo Ventures': 1,
#          'FiNC, GHV': 1,
#          'Fidelity Growth Partners': 1,
#          'Fidelity Growth Partners India, SAIF Partners,\xa0 Helion Ventures': 1,
#          'Fidelity Growth Partners, Fidelity Biosciences': 1,
#          'Fireside Ventures & Others': 1,
#          'Fireside Ventures, Apurva Salarpuria, Sidharth Pansari, Sprout Capital': 1,
#          'Fireside Ventures, Investopad, P39 Capital, Anupam Mittal, Pranay Jivrajka, Maninder Gulati, Abhinav Sinha': 1,
#          'Fireside Ventures, Mumbai Angels MAPE Advisory Group.': 1,
#          'Flipkart': 3,
#          'Flipkart Logistics Pvt. Ltd': 1,
#          'Flipkart, Accel Partners, Delhivery, Foxconn': 1,
#          'Flipkart, Saavn, Micromax, Dhiraj Rajaram, Ambiga Dhiraj, Dinesh Agarwal, Samir Bangara, Sanjay Nath, Arihant Patni': 1,
#          'Flipkart, Tiger Global': 1,
#          'Florida based Angel investor': 1,
#          'Florintree, Mathew Cyriac, Chidambaram Palaniappan, Bharat Sheth': 1,
#          'Ford Smart Mobility Llc': 1,
#          'Fork Media': 1,
#          'Forum Synergies PE Fund': 1,
#          'Fosun International': 1,
#          'Foxconn Technology Group & Others': 1,
#          'Francesco Cara': 1,
#          'Franchise India': 2,
#          'Franklin Templeton International Services Pvt. Ltd': 1,
#          'FreakOut Group, Blume Ventures, Herb Madan, WaterBridge Ventures': 1,
#          'Frontline Strategy': 1,
#          'Funding through 1Crowd platform': 1,
#          'Future Fund,Bessemer Venture, Capricorn Investment and IFC': 1,
#          'GAIN': 1,
#          'GBIM Technologies Pvt Ltd': 1,
#          'GEMS Advisory, Quarizon': 1,
#          'GEMS group': 1,
#          'GEMs': 1,
#          'GEMs Advisory, Quarizon': 1,
#          'GHV Accelerator': 3,
#          'GIC': 1,
#          'GIC ventures': 1,
#          'GIC, Tiger Global Management, Nexus Venture Partners': 1,
#          'GMO Japan, Neelesh Bhatnagar': 1,
#          'GMO Payment Gateway, MediaTek': 1,
#          'GPA group': 1,
#          'GREE Ventures, Kalaari Capital and IDG Ventures India, Summit Media, Atul Goel, and Gurpreet Singh': 1,
#          'GREX': 1,
#          'GROUPE SOS': 1,
#          'GVFL': 1,
#          'GVFL Ltd': 1,
#          'GVFL, Unicorn India Ventures': 1,
#          'GWB Group, Blume Ventures': 1,
#          'Gaja Capital Private Equity Fund': 1,
#          'Ganesh Narasimhan, Ramana Thumu, Sudhir Mallem': 1,
#          'Ganesh Natarajan': 2,
#          'GardX International': 1,
#          'Gati Ltd': 1,
#          'Gaurav Kachru, Sundeep Singh Sahni, Jatin Aneja, Arun Malhotra': 1,
#          'Gaurav Singhvi, Zaffiro Ventures': 1,
#          'General Catalyst Partners': 1,
#          'General Catalyst, Founder Collective': 1,
#          'Geniee, Inc, Purvi Capital': 1,
#          'Girish Mathrubootham, Phanindra Sama, Vikram Chachra, Others from LetsVenture': 1,
#          'Girish Mathrubootham, VC Karthic, Miten Mehta, Umasankar Nistala, Rakesh Patel, Akash Bhavsar, Jeevanandhan Rajagopal, Vikas Chadha & Others': 1,
#          'GirnarSoft': 2,
#          'Gleevoaz Ventures': 1,
#          'Globevestor Angel Fund, Devendra Rane, Ravi Jain,\xa0 Arpan Nagdeve': 1,
#          'Gokaldas Exports Ltd': 1,
#          'Gokul Jaykrishna, Brand Capital': 1,
#          'Goldman Sachs': 2,
#          'Goldman Sachs Group, Zodius Technology Fund, Norwest Venture Partners, Bertelsmann India': 1,
#          'Goldman Sachs, Rocket Internet': 1,
#          'Goldman Sachs, Zodius Capital': 1,
#          'Goldman Sachs, Zodius Technology Fund, Bertelsmann India Investments Norwest Venture Partners.': 1,
#          'Google Capital': 2,
#          'Gopal Aggarwal': 1,
#          'Gopal Srinivasan, Sashi Reddy, Amit Gupta, Pallav Nadhani': 1,
#          'Gordon and Betty Moore Foundation': 1,
#          'Grace Capital Ventures': 1,
#          'Grace Grace Techno Ventures LLP, Rajul Garg & Other undisclosed investors': 1,
#          'Grasshoppers': 1,
#          'Gray Matters Capital': 3,
#          'Green House Ventures': 2,
#          'Green House Ventures (GHV)': 4,
#          'Green House Ventures Accelerator': 1,
#          'Greenoaks capital, Sequoia Capital, LightSpeed Ventures': 1,
#          'Grex.in': 2,
#          'Greycroft Partners, Fidelity Growth Partners': 1,
#          'Group of 15 Angel Investors': 1,
#          'Group of Angel Investors': 15,
#          'Group of Angel Investors from US/India': 1,
#          'Group of Angel investors': 2,
#          'Group of HNI investors': 1,
#          'Group of Investors': 2,
#          'Group of angel investors': 3,
#          'Group of undisclosed Angel Investors & HNIs': 1,
#          'GrowX Ventures': 1,
#          'GrowX Ventures, Kunal Shah, Sandeep Tandon, Haresh Chawla, Powai Lake Ventures, Globevestor': 1,
#          'GrowX Ventures, Sunil Kalra, Arun Venkatachalam,\xa0 Badal Malick': 1,
#          'GrowX ventures, Tracxn Labs, Powai Lake Ventures, and Sahil Barua': 1,
#          'GrowthStory': 1,
#          'GrowthStory, Apurva Salapuria, Hitesh Oberoi, Sidharth Pansari, Nirupa Shankar': 1,
#          'Growx Ventures, Manish Singhal': 1,
#          'Gujarat Venture Finance Limited (GVFL), Bennett Coleman & Co. Ltd': 1,
#          'Gujarat Venture Finance Ltd': 1,
#          'Gujarat based angel investors, MMY co-Founder': 1,
#          'Guy Oseary': 1,
#          'HAX Accelerator': 1,
#          'HBM Healthcare Investments': 1,
#          'HBM Healthcare Investments, Maverick Capital Ventures, Sequoia India, Omidyar Network and Kae Capital': 1,
#          'HCS Venture capital fund': 1,
#          'HDFC Bank': 1,
#          'HDFC, Faering Capital, Elevate Sports': 1,
#          'HR Technology fund': 1,
#          'HT Digital Media Holdings Ltd': 1,
#          'HT Media Ltd': 1,
#          'HT Media Ltd, North Base Media': 1,
#          'HT Media, Arun Duggal': 1,
#          'Hampton Capital': 1,
#          'Hamraj Kumar': 1,
#          'Hari Krishna, Ajay Modani, Dr V Ravinder, Anirudh Rastogi, Abhishek Jain, Rakesh Gakhar, Rajeev Mudumba, Nagendra Prasad Bhanuprakash': 1,
#          'Harinder Takhar, Zain Raj, Dr. Prasad Kaipa, Abaran Deep, Aseem Sood, Mustafa Patni': 1,
#          'Harmeet Bajaj, Pameela P, Fusiontech Ventures & Others': 1,
#          'Harminder Sahni, Krishna Mehra, Sanjay Bakshi': 1,
#          'Harmony Partners, RB Investments & existing investors': 1,
#          'Harsh Mahajan, Farhan Naqvi, Sreepathy Viswanathan': 1,
#          'Harsh Mariwala, Atul Nishar, Dalip Pathak, Michael Carlos': 1,
#          'Harsh V. Pant, Ratheesh Raveendran': 1,
#          'Harsh Vardhan Hada': 1,
#          'Helion Venture Partner, Powerhouse Ventures, GSF and Other angel investors': 1,
#          'Helion Venture Partners': 1,
#          'Helion Venture Partners, BeeNext': 1,
#          'Helion Venture Partners, Exfinity Ventures': 1,
#          'Helion Venture Partners, Kae Capital': 1,
#          'Helion Venture Partners, Kalaari Capital': 1,
#          'Helion Venture Partners, Orios Venture Partners': 1,
#          'Helion Venture Partners,Amarpreet Sawhney, Deshpande Foundation, Fred Khosravi, Richard S. Braddock': 1,
#          'Helion Ventures, Blume ventures': 1,
#          'Helion Ventures, Jungle Ventures & Bessemer Venture Partners': 1,
#          'Helion Ventures, Omidiyar Network, Blume Ventures and Ujama': 1,
#          'Hemang Sahani': 1,
#          'Hemant Sahni': 1,
#          'Hero MotoCorp': 1,
#          'High Networth Individuals (No details)': 1,
#          'High Networth Individuals (undisclosed)': 1,
#          'High Networth Individuals from India & USA': 1,
#          'Hillhouse Capital, Tybourne Capital': 1,
#          'Hinduja family': 1,
#          'Hitesh Windlass': 1,
#          'Hitouch AG': 1,
#          'Holostik Group, YouWeCan Ventures, 500 Startups, Vijay Shekhar Sharma, Manish Kheterpal, Amit Patni': 1,
#          'Horizons Ventures, Capricorn Investment Group, Social+Capital, Helion Advisors, Berggruen Holdings': 1,
#          'Huzaifa Khorakiwala': 1,
#          'Hyderabad Angels': 2,
#          'Hyderabad Angels (at Startup Heroes event)': 5,
#          'Hyderabad Angels, Lalit Mangal,\xa0 Vikas Malpani, Gaurav Bhalotia, LV Prasad': 1,
#          'Hyderabad Angels, M&S Partners': 1,
#          'Hyderabad Angels, Singapore Angel Network, Ness Wadia': 1,
#          'Hyderabad Angels, TLabs': 1,
#          'Hyderabad based investor': 1,
#          'I-cube-N': 1,
#          'IAN Ventures, Alok Sharma, Kris Gopalakrishnan, Saurabh Srivastava, Ajai Chowdhry': 1,
#          'ID Enablers Pvt Ltd': 1,
#          'IDFC Parampara Early Stage Opportunities Fund': 1,
#          'IDFC SPICE Fund, Micromax Informatics': 1,
#          'IDG Ventures': 3,
#          'IDG Ventures India': 1,
#          'IDG Ventures India Advisors, Jungle Ventures': 1,
#          'IDG Ventures India, Elevar Equity, Accion Venture Lab': 1,
#          'IDG Ventures India, Inventus Capital, Blume Ventures': 1,
#          'IDG Ventures India, Jungle Ventures, India Quotient.': 1,
#          'IDG Ventures India, Kalaari Capital, 500 Startups': 1,
#          'IDG Ventures India, Michael & Susan Dell Foundation, Draper Associates, Unitus Seed Fund': 1,
#          'IDG Ventures India, Omidyar Network, Sherpalo Ventures,\xa0 Mohandas Pai': 1,
#          'IDG Ventures India,\xa0 Accel Partners India': 1,
#          'IDG Ventures, Accel Partners': 1,
#          'IDG Ventures, Axilor Ventures': 1,
#          'IDG Ventures, Blume Ventures, Saha Fund,': 1,
#          'IDG Ventures, Endiya Partners': 1,
#          'IDG Ventures, Indian Angel Network (IAN), YourNest Angel Fund': 1,
#          'IDG Ventures, Inventus Capital, Indian Angel Network': 1,
#          'IDG Ventures, Kris Gopalakrishnan': 1,
#          'IDG Ventures, M & S partners, Powerhouse Ventures (USA).': 1,
#          'IDG Ventures, Naveen Tewari': 1,
#          'IDG Ventures, Outbox Ventures': 1,
#          'IDG Ventures, Sequoia Capital': 1,
#          'IDG Ventures, Sequoia Capital, GREE Ventures': 1,
#          'IDG ventures, Axilor Ventures, Emergent Ventures, Indian Angel Network': 1,
#          'IDG, Indian Angel Network': 1,
#          'IFC Everstone Group': 1,
#          'IFC, Axon Partners, Intel Capital': 1,
#          'IFMR Capital Finance': 1,
#          'IIFL Seed Ventures Fund, Mayfield Ventures': 1,
#          'IIFL Seed Ventures, Kae Capital, FJ Labs, Singularity Ventures, GrowX, Tracxn Labs, Axis Capital': 1,
#          'IIFL Wealth Management Seed Venture Fund, Omidyar Network, Khosla Impact, Aspada': 1,
#          'IIFL and Accel Partners, Kalaari Capital, IvyCap Ventures, RB Investments': 1,
#          'Ibibo Group': 1,
#          'Idea Wave Labs': 1,
#          'IdeaSpring Capital': 1,
#          'Ideaspring Capital': 3,
#          'Idein Ventures': 4,
#          'Ignition Partners, Greycroft Partners, Fidelity Growth Partners India': 1,
#          'Impact Investment Holding, Upaya Social Ventures': 1,
#          'Impanix Capital': 1,
#          'Inara Capital , Rishi Khiani': 1,
#          'Incubate Fund, Lead Angels Group & Others': 1,
#          'India Educational Investment Fund': 5,
#          'India Nivesh Growth Fund, Sixth Sense, TCI Ventures': 1,
#          'India Quotient': 5,
#          'India Quotient & other investors': 1,
#          'India Quotient and others': 1,
#          'India Quotient, Anupam Mittal & others': 1,
#          'India Quotient, FAO Ventures, Indian Angel Network, Tushar Singh, Ranjan Sharma': 1,
#          'India Quotient, Kae Capital': 1,
#          'India Quotient, LetsVenture investors, Lead Angels': 1,
#          'India Quotient, Rajul Garg, Rajesh Yabaji, Chanakya Hridaya, Ramasubramaniam B, Vishwanathan, Nobel House, Sunstone Capital': 1,
#          'India Quotient, Shunwei Capital': 1,
#          'India Value Fund Advisors': 1,
#          'India Ventures, Aarin Capital & Others': 1,
#          'IndiaMart': 1,
#          'IndiaNivesh Venture Capital Fund': 1,
#          'Indian Angel Network': 24,
#          'Indian Angel Network (IAN), BEENEXT, The Chennai Angels, Sunil Munjal': 1,
#          'Indian Angel Network,': 1,
#          'Indian Angel Network, Alok Sharma, Kris Gopalakrishnan, Saurabh Srivastava, and Ajai Chowdhry': 1,
#          'Indian Angel Network, Anand Mahindra': 1,
#          'Indian Angel Network, Healthsquad, Axilor Ventures': 1,
#          'Indian Angel Network, Let’s Venture': 1,
#          'Indian Angel Network, Native Angels Network': 1,
#          'Indian Angel Network, Stanford Angels, Entrepreneurs India': 2,
#          'Indian Angel Network, Tracxn Labs & Others': 1,
#          'Indian Angel network': 1,
#          'Indian Angels Network': 1,
#          'Indian Angels Network, LetsVenture': 1,
#          'IndianIdeas.com': 1,
#          'Indochine International': 1,
#          'Infibeam': 1,
#          'Infibeam, CCavenue': 1,
#          'Infina Finance Pvt. Ltd, Uday Kotak': 1,
#          'Inflexionpoint, Pramod Bhasin, Sixth Sense Ventures, Vindi Banga, Hiro Mashita': 1,
#          'Info Edge': 1,
#          'Info Edge (India)': 2,
#          'Info Edge (India) Ltd': 8,
#          'InfoEdge': 1,
#          'Infosys': 1,
#          'Infuse Ventures': 4,
#          'Infuse Ventures fund': 1,
#          'Infuse Ventures, JLL': 1,
#          'Infuse Ventures, Low Carbon Enterprise Fund': 1,
#          'Infuse Ventures, The Chennai Angels': 1,
#          'Ingram Content Group': 1,
#          'InnoVen Capital': 3,
#          'InnoVen Capital India': 1,
#          'Innovations East': 1,
#          'Innoven Capital': 1,
#          'Insitor Impact Asia Fund, Acumen Fund': 1,
#          'Instalabs': 1,
#          'Institutional Venture Partners, Norwest Venture Partners, Lightspeed Venture Partners, CRV': 1,
#          'Intellecap Impact Investment Network, family office fund': 1,
#          'Intelli Reboot Digital Pvt. Ltd': 1,
#          'InterGlobe Technology Quotient, Lantern Capital': 1,
#          'International Finance Corp, TPG Growth, Adveq Management, IDG Ventures, Ratan Tata, Kris Gopalakrishnan': 1,
#          'International Finance Corporation': 1,
#          'International Finance Corporation, Rocketship, Accel Partners, Jungle Ventures, Shailesh Rao, Venture Highway': 1,
#          'International Financial Corporation': 1,
#          'Intex Technologies': 1,
#          'Inventus Capital Partners, Blume Ventures & Others': 1,
#          'Inventus Capital Partners, HR Fund': 1,
#          'Inventus Capital Partners, IDG Ventures': 1,
#          'Investors from Mumbai Angels & LetsVenture': 1,
#          'Iron Pillar and IIFL, Blume Ventures, Omidyar Network': 1,
#          'Ishan Manaktala': 1,
#          'Ishwar Singh,Farhaan Shabbir': 1,
#          'Ivy League Alumni Angel Network': 1,
#          'IvyCamp Ventures': 2,
#          'IvyCap Ventures': 4,
#          'IvyCap Ventures and Unicorn India Ventures': 1,
#          'IvyCap Ventures, Accel Partners, Dragoneer Investment Group': 1,
#          'IvyCap Ventures, Inventus Capital': 1,
#          'IvyCap Ventures, Orios Venture Partners, Mayfield India': 1,
#          'Ivycap Ventures Advisors, Singularity Ventures and Ravi Dhariwal': 1,
#          'JAFCO Asia, Keystone Group, Dragoneer Investment, Accel Partners': 1,
#          'JLL, 1Crowd': 1,
#          'JM Financial Products Ltd, Arun Tadanki, Doreswamy Nandkishore, Kshitij Jain': 1,
#          'JMR Infotech India Pvt Ltd': 1,
#          'JS Capital, Helion Venture Partners, Capricorn Investment Group': 1,
#          'JSW Ventures, Blume Ventures & IvyCap Ventures': 1,
#          'JSW Ventures, Omidyar Network, Sattva Capital, Venture Works': 1,
#          'JSW Ventures, VenturEast': 1,
#          'Jaarvis Accelerator': 1,
#          'Jacqueline Fernandez': 1,
#          'Jai Choi, Kiyohiro Sugashita, Hirokazu': 1,
#          'Jaideep Mehta': 1,
#          'Jan Manten': 1,
#          'Janak Jain': 1,
#          'Janak Parikh': 1,
#          'Japan Vyas, Tarun Adlakha': 1,
#          'Jaspal Bindra, Parth Jindal': 1,
#          'Jasper Infotech Pvt Ltd': 1,
#          'Jay Vijayan': 1,
#          'Jayabalan Subramanian': 1,
#          'Jayant Bokadia': 1,
#          'Jaydeep Barman': 1,
#          'Jitendra Gupta': 1,
#          'Jitendra Gupta & others': 1,
#          'Jitendra Gupta, Pankaj Tripathi': 1,
#          'Jitu Virwani': 1,
#          'Jozef Bardik, Leo Wang Sangeeth Ram': 1,
#          'Jungle Ventures': 4,
#          'Jungle Ventures, Redbright Partners, Blume Ventures': 1,
#          'Jungle Ventures, Taurus Value Creation, Konly Venture, Blume Ventures': 1,
#          'Jupiter Capital': 1,
#          'Justin Kan, Qasar Younis, Paul Bucche, Susa Ventures, Kima Ventures, Axan Venture, SCM Holdings': 1,
#          'K2 Capital': 1,
#          'KAE capital': 1,
#          'KARSEMVEN Fund': 1,
#          'KCL': 1,
#          'KJS Group': 1,
#          'KStart Capital': 1,
#          'KTB Network, SAIF Partners, BEENEXT, Digital Garage': 1,
#          'KWAN Entertainment & Marketing Solutions, Powerhouse Ventures & Others': 1,
#          'Kae Capital': 4,
#          'Kae Capital, Anoop Goyal, Mike Shah, VA Sastry': 1,
#          'Kae Capital, Anupam Mittal': 1,
#          'Kae Capital, GSF, Teruhide Sato': 1,
#          'Kae Capital, India Quotient, IFMR, and MAS Financial Services Ltd': 1,
#          'Kae Capital, Khosla Impact': 1,
#          'Kae Capital, Kunal Bahl, Rohit Bansal': 1,
#          'Kae Capital, Kunal Shah, Sandeep Tandon': 1,
#          'Kae Capital, M&S Partners,': 1,
#          'Kae Capital, SEGNEL Ventures': 1,
#          'Kaizen Management Advisors, DeVry Inc': 1,
#          'Kaizen Private Equity': 1,
#          'Kalaari Capital': 16,
#          'Kalaari Capital Accelerator Program': 3,
#          'Kalaari Capital Partners, Qualcomm, 3ONE4 Capital Advisors, UC-RNT': 1,
#          'Kalaari Capital, IDG Ventures India': 1,
#          'Kalaari Capital, India Quotient': 2,
#          'Kalaari Capital, Inventus Capital, Tekton Ventures, Kae Capital': 1,
#          'Kalaari Capital, Nexus India Capital Advisors': 1,
#          'Kalaari Capital, Norwest Venture Partners': 2,
#          'Kalaari Capital, Qualcomm Ventures, ru-Net, Zodius Technology Opportunities Fund,': 1,
#          'Kalaari Capital, Rakesh and Rajesh Jhunjhunwala': 1,
#          'Kalaari Capital, SAIF Partners, Beenextan investment fund': 1,
#          'Kalaari Capital, SAIF Partners, Steadview Capital, Sequoia Capital': 1,
#          'Kalaari Capital, Sequoia Capital': 1,
#          'Kalaari Capital, Udayan Goyal': 1,
#          'Kalaari Capital, YourNest Angel Fund': 1,
#          'Kanodia family, Amit Banka': 1,
#          'Kanpur Angels & Others': 1,
#          'Kanwaljit Singh, Ajay Lakhotia, Pavan Ongole, Ashish Gupta': 1,
#          'Kanwaljit Singh, Angie Mahtaney, Manoj Varghese': 1,
#          'Kanwaljit Singh, Shripad Nadkarni, Sarvesh Shahra & Others': 1,
#          'Kanwaljit Singh, TV Mohandas Pai': 1,
#          'Kapil Goel': 1,
#          'Karan Bajwa, Amanpreet Bajaj, Manish Vij': 1,
#          'Karan Bajwa, Parvesh Bareja , Sunjay Kapur, Amanpreet Bajaj': 1,
#          'Karan Bhagat': 1,
#          'Karanpal Singh': 1,
#          'Karanpal Singh & Others': 1,
#          'Karnataka Semiconductor Venture Capital firm': 1,
#          'Kashyap Deorah, Anand Sankeshwar, Deepak Jain, Sadashiva NT, Arjun Mehta, Satish Kaul, Anindya Ghose': 1,
#          'Kashyap Deorah, Rajul Garg, Maninder Gulati': 1,
#          'Katabole Technology Venture': 1,
#          'Kaushal Agarwal, Harminder Sahani, KK Mehra, Pranay Jivrajka, Navjot Saini': 1,
#          'Kedar Lele, GHV Accelerator': 1,
#          'Keiretsu Forum': 1,
#          'KellyGamma, Lead Angels & Others': 1,
#          'Kemark Ventures, Amit Ranjan, Zishaan Hayath and Others': 1,
#          'Keyur Joshi, Pavan Bakeri': 1,
#          'Khattar Holdings, ThirtyThree Investments, Soumitra Sharma, Deepak Sharma, Sumit Dayal and others': 1,
#          'Khazanah Nasional Berhad': 1,
#          'Khazanah Nasional Berhad, Helion Venture Partners': 1,
#          'Khosla Impact, Biz Stone, Catamaran Ventures, Global Founders Capital, European investment fund': 1,
#          'Kickstarter': 1,
#          'Kinnevik Group, Rocket Internet': 1,
#          'Kiran Mazumdar-Shaw, Unitus Seed Fund': 1,
#          'Kirthiga Reddy, Renuka Ramanath,Cherry Tin': 1,
#          'Kleiner Perkins, Goldman Sachs, Pine Brook': 1,
#          'Kludein LLCPhanindra Sama, Narayan Ramachandran, Pranav Pai': 1,
#          'Koen Bouwers, Lomesh Agarwal, Jeroen Mensen, Pablo van den Bosch & Others': 1,
#          'Konglo Ventures, White Unicorn Ventures, LetsVenture': 1,
#          'Kris Gopalakrishnan & Others': 1,
#          'Kris Gopalakrishnan, Atul Nishar': 1,
#          'Kris Gopalakrishnan, Dr. Ranjan Pai': 1,
#          'Kris Gopalakrishnan, Nagaraja Prakasam': 1,
#          'Krishna Jhujhunwala, Dr. Apoorv Ranjan Sharma, Anirudh Damani, Anand Ladsariya, Sanjay Mehta & Others': 1,
#          'Krishna Rokhale': 1,
#          'Kstart Capital': 1,
#          'Kunal Bahl, Rohit Bansal': 2,
#          'Kunal Bahl, Rohit Bansal, Blume Ventures, Phanindra Sama, Raju Reddy': 1,
#          'Kunal Bahl, Rohit Bansal, Pranay Chulet, Naveen Tiwari, Amit Gupta, Mayank Singhal': 1,
#          'Kunal Bahl, Rohit Bansal, Zishaan Hayath, Prashant Malik': 1,
#          'Kunal Bajaj, Chandru Badrinarayanan': 1,
#          'Kunal Shah & Sandeep Tandon, Girish Mathrubootham, Anand Chandrasekaran': 1,
#          'Kunal Shah, Aneesh Reddy, Tracxn Labs, Venkat Tadanki, Krishna Mehra, Amit Rathore': 1,
#          'Kunal Shah, LetsVenture, Anupam Mittal, Hetal Sonpal': 1,
#          'Kunal Shah, Sandeep Tandon': 1,
#          'Kunal Shah, Sandeep Tandon, Nitin Saluja, Gagan Goyal': 1,
#          'Kunal Shah, Sandeep Tandon, Tracxn Labs': 1,
#          'LGT Group, Asian Healthcare fund, Seedfund': 1,
#          'Labruyere Eberlé': 1,
#          'Lahiri Music’s family office': 1,
#          'Lakshmi Vilas Bank & undisclosed HNIs': 1,
#          'Lalit Mangal & Others': 1,
#          'Lalit Vase': 1,
#          'Lalitesh Katragadda,\xa0 Ganayantrika Systems': 1,
#          'Langoor': 1,
#          'Lashit Sanghvi, Nikhil Vora, Venkat Vardhan,Mohammed Bin Abdul Rehman Al Khalifa,\xa0 Ralph Berezan, Vissal Mathew,\xa0 Balamurali Krishna': 1,
#          'Lead Angel Network': 1,
#          'Lead Angels': 3,
#          'Lead Angels Network, Anbu Pandian, Prabhakar MR & Others': 1,
#          'Lead Angels, Mumbai Angels, LetsVenture, Girish Mathrubootham, Anbu Pandian': 1,
#          'Lemelson Foundation, Michael and Susan Dell Foundation': 1,
#          'Lensbridge Capital, Mape Advisory Group, Fireside Ventures': 1,
#          'LetsVenture': 3,
#          'LetsVenture, Kumar Bansal, Kshitij Jain': 1,
#          'LetsVenture, Mohandas Pai': 1,
#          'LetsVenture, Mumbai Angels': 1,
#          'Li Tao, Li Jian, Draphant Consultants, Nitin Garg, Saurabh Jain, Mohit Agarwal': 1,
#          'Life.SREDA, Qualgro': 1,
#          'LightBox Ventures': 1,
#          'Lightbox Ventures': 2,
#          'Lightbox Ventures and others': 1,
#          'Lightbox Ventures, Axis Capital & Others': 1,
#          'Lightbox Ventures, Beenos': 1,
#          'Lightspeed India': 2,
#          'Lightspeed India Partners, Blume Ventures, CyberAgent Ventures, GrowX Ventures, IMJ Investment Partners': 1,
#          'Lightspeed India Partners, Endiya Partners, 3one4 Capital Advisors LLP, Startupxseed Ventures LLP': 1,
#          'Lightspeed India Partners, SAIF Partners, India Quotient, Venture Highway': 1,
#          'Lightspeed India Partners, Waterbridge Ventures': 1,
#          'Lightspeed Venture Partners': 2,
#          'Lightspeed Venture Partners India, Lightspeed US': 1,
#          'Lightspeed Venture Partners, K Ganesh': 1,
#          'Lightspeed Venture Partners, Vy Capital,': 1,
#          'Lightspeed Ventures': 1,
#          'Ligthbox Ventures II, Lightbox Expansion Fund, Sequoia Capital India, RuNet South Asia, RB Investments': 1,
#          'Lion Ventures': 1,
#          'LionRock Capital': 1,
#          'Lip-Bu Tan, Michael Marks, Nicolas Braithwaite': 1,
#          'Logtally': 1,
#          'Lohia Group, Andre Hoffman': 1,
#          'Lothal Angel Ventures': 1,
#          'Lumis Partners, The HR Fund, Rajul Garg, Quintillion Media': 1,
#          'Luxasia Group': 1,
#          'L’Occitane': 2,
#          'M&S Partners': 1,
#          'M&S Partners Pte. Ltd': 1,
#          'M&Y Partners, SVG Media, Anthil Ventures & others': 1,
#          'MAPE Advisory Group, R Ramaraj, Corvus Ventures': 1,
#          'MCube Capital Advisors Pvt Ltd': 1,
#          'MCube8': 1,
#          'MadhanKumar Madathupalayam': 1,
#          'Madhukar Gangadi, Satish Reddy, Srini Raju, Srini Koppolu & SIDBI': 1,
#          'Mahalingam K, Girish Mathrubootham': 1,
#          'Mahavir Pratap Sharma': 1,
#          'Mahavir Pratap Sharma, Ajay Data, Yogesh Chaudhary, Sanjay Phophaliya, Siddharth Agarwal, Kamal Kothari': 1,
#          'Mahavir Sharma, Vishal Jain, Rohit Sethi, Gaurav Luniya': 1,
#          'Mahendra Patel, Nilender Chauhan': 1,
#          'Mahesh Parasuraman, Rahul Gautam & Others': 1,
#          'Mahesh Pratapneni, Pallab Chatterjee & others': 1,
#          'Mahindra Holidays & Resorts India Ltd': 1,
#          'Mahindra Partners, Eight Roads Ventures, F-Prime Capital Partners': 1,
#          'Mahindra Univeg': 1,
#          'Mahindra and Mahindra Financial Services': 1,
#          'MakeMyTrip': 3,
#          'MakeMyTrip Innovation Fund': 1,
#          'Malini Patel, Stelcore Management Services, Anjani Prasad': 1,
#          'Man Capital': 1,
#          'Mandeep Singh, Jairaj Singh': 1,
#          'Mangrove Capital Partners': 1,
#          'Mangroves Capital Partners, Vikas Saxena': 1,
#          'Manipal Education and Medical Group (MEMG), SAR Group, The Grover Trust': 1,
#          'Manipal Global Education Services': 2,
#          'Manipal Group': 1,
#          'Manish Dhingra, Ankush Nijhawa, Gaurav Bhatnagar': 1,
#          'Manish Gupta': 1,
#          'Manish Kheterpal, Alok Mittal,\xa0 Puneet Dalmia,': 1,
#          'Manish Kheterpal, Vinay Mittal, Dinesh Mittal, Sandeep Gupta': 1,
#          'Manish Maheshwari, Contrarian Vriddhi Fund': 1,
#          'Manish Singhal, P39 Capital & Others': 1,
#          'Manoj Kumar & Other undisclosed investors': 1,
#          'Manpreet Singh': 1,
#          'Mape Advisory': 1,
#          'Maple Capital Advisors': 1,
#          'MapmyIndia': 1,
#          'Marico Innovation Foundation (MIF), Villgro': 1,
#          'Mark Mobius & 9 Other Angel investors': 1,
#          'MasterCard': 1,
#          'Mathew Cyriac, Florintree Advisors,': 1,
#          'Mato Peric, Peter Kabel & others': 1,
#          'Matrix Partners': 3,
#          'Matrix Partners India': 3,
#          'Matrix Partners India, India Quotient': 1,
#          'Matrix Partners India, SAIF Partners': 1,
#          'Matrix Partners, Nexus Ventures': 1,
#          'Matrix Partners, Sequoia Capital, Nexus Venture Partners': 1,
#          'Matt Glickman': 1,
#          'Matt Mullenweg, Adam D’Angelo, Aditya Agarwal,\xa0 Ruchi Sanghvi & Others': 1,
#          'Maverick Capital Ventures, Sequoia Capital, Omidyar Network': 1,
#          'Maverick Capital, IDG Ventures India': 1,
#          'Max Levchin, Scott Banister': 1,
#          'Max Ventures and Industries': 1,
#          'Mayank Shah, Shreyans Shah': 1,
#          'Mayank Singhal and others': 1,
#          'Mayfield India II Management Ltd': 1,
#          'Mayfield India, 3one4 Capital, Sistema Asia Fund, Neoplux Technology Fund': 1,
#          'Mayfield India, Kalaari Capital, Helion Ventures': 1,
#          'Mayfield India, Trifecta Capital': 1,
#          'Mayfield Ventures': 2,
#          'Mayfield Ventures, Kalaari Capital': 1,
#          'Mayfield Ventures, Kalaari Capital, Helion Ventures': 1,
#          'Mayfield, Nishant Rao, Dileep Nath': 1,
#          'Medi Assist': 1,
#          'MediaTek Inc.': 1,
#          'Meher Roy, Nikhil Arora, Meet Kanodia, Krit Sankalp, Nitish Singh, Risabh Gupta': 1,
#          ...})

# %% [markdown]
# # Top Industries

# %%
from collections import Counter
import pandas as pd
import operator
data = pd.read_csv('startup_funding.csv', skipinitialspace=True)

# Empty values fill
data['AmountInUSD'] = data['AmountInUSD'].fillna('0,0')
data = data.fillna('None')

# AmountInUSD contains ','
data['AmountInUSD'] = data['AmountInUSD'].str.replace(',','')
data['AmountInUSD'] = data['AmountInUSD'].astype(int)

temp = data.index[data['IndustryVertical'].str.lower() == 'ecommerce']

data.at[temp, 'IndustryVertical'] = 'Ecommerce'
data = data.groupby('IndustryVertical').sum()
data = data.sort_values(by='AmountInUSD', ascending=False)
data = data.drop(index= 'None')
del data['SNo']

data = data[:5]
total = data['AmountInUSD'].sum()

ans = dict(zip(data.index.values.tolist(), data['AmountInUSD'].tolist()))
for i in ans: 
    print("{} {:.2f}".format(i, (ans[i] * 100)/total))
# Out:
# Ecommerce 40.53
# Consumer Internet 35.95
# Technology 10.45
# Online Marketplace 6.63
# E-Commerce & M-Commerce platform 6.44

# %% [markdown]
# # Top startups

# %%
from collections import Counter
import pandas as pd
import operator
data = pd.read_csv('startup_funding.csv', skipinitialspace=True)

# Empty values fill
data['AmountInUSD'] = data['AmountInUSD'].fillna('0,0')
data = data.fillna('None')

# AmountInUSD contains ','
data['AmountInUSD'] = data['AmountInUSD'].str.replace(',','')
data['AmountInUSD'] = data['AmountInUSD'].astype(int)

ola = {'Ola Cabs': 'Ola', 'Olacabs': 'Ola','Paytm Marketplace': 'Paytm', 'Flipkart.com': 'Flipkart',
       'OyoRooms': 'Oyo', 'Oyo Rooms': 'Oyo', 'OYO Rooms': 'Oyo', 'OyoRooms': 'Oyo', 'Oyorooms': 'Oyo'}
data = data.replace(ola)
data = data.groupby('StartupName').sum()
data = data.sort_values(by='AmountInUSD', ascending=False)
del data['SNo']

data = data[:5]
total = data['AmountInUSD'].sum()

for i in data.index.values.tolist(): 
    print(i)
# Out:
# Paytm
# Flipkart
# Ola
# Snapdeal
# Oyo

# %% [markdown]
# # Funding Rounds

# %%
from collections import Counter
import pandas as pd
import operator
data = pd.read_csv('startup_funding.csv', skipinitialspace=True)

# Empty values fill
data['AmountInUSD'] = data['AmountInUSD'].fillna('0,0')
data = data.fillna('None')

# AmountInUSD contains ','
data['AmountInUSD'] = data['AmountInUSD'].str.replace(',','')
data['AmountInUSD'] = data['AmountInUSD'].astype(int)

ola = {'Ola Cabs': 'Ola', 'Olacabs': 'Ola','Paytm Marketplace': 'Paytm', 'Flipkart.com': 'Flipkart',
       'OyoRooms': 'Oyo', 'Oyo Rooms': 'Oyo', 'OYO Rooms': 'Oyo', 'OyoRooms': 'Oyo', 'Oyorooms': 'Oyo'}
data = data.replace(ola)
temp = Counter(data['StartupName'])
temp = sorted(temp.items(), key=operator.itemgetter(1), reverse=True)[:5]
for i in temp:
    print(i[0], i[1])
# Out:
# Ola 9
# Swiggy 7
# UrbanClap 6
# Paytm 6
# Oyo 6

# %% [markdown]
# # Top Investor

# %%
from collections import Counter
import pandas as pd
import numpy as np
import operator

data = pd.read_csv('startup_funding.csv', skipinitialspace=True)
rep = {'Undisclosed Investors': 'None', 'Undisclosed investors': 'None', 'Undisclosed Investor': 'None',
      'Undisclosed investor': 'None', 'Undisclosed': 'None'}
data['InvestorsName'] = data['InvestorsName'].replace(rep)
data['InvestorsName'] = data['InvestorsName'].str.split(',')

temp = np.array(data['InvestorsName'].tolist())
temp = np.char.strip(np.hstack(temp), ' ').tolist()
investors = Counter(temp)
investors = sorted(investors.items(), key=operator.itemgetter(1), reverse=True)[:5]
print(investors[1][0], investors[1][1])
# Out:
# Sequoia Capital 64
